# %% [markdown]
# ##**INTRODUCTION:**
#
# The dataset consists of historical sales data of a supermarket company from 3 different branches over 3 months.
# Following table provides a summary of the variables and the variable description.

# %% [markdown]
# ###**DATA SET EXPLANATION:**
#
# Invoice id: Computer generated sales slip invoice identification number
#
# Branch: Branch of supercenter (3 branches are available identified by A, B and C).
#
# City: Location of supercenters
#
# Customer type: Type of customers, recorded by Members for customers using member card and Normal for without member card.
#
# Gender: Gender type of customer
#
# Product line: General item categorization groups - Electronic
# accessories, Fashion accessories, Food and beverages, Health and beauty, Home and lifestyle, Sports and travel
#
# Unit price: Price of each product in $
#
# Quantity: Number of products purchased by customer
#
# Tax: 5% tax fee for customer buying
#
# Total: Total price including tax
#
# Date: Date of purchase (Record available from January 2019 to March 2019)
#
# Time: Purchase time (10am to 9pm)
#
# Payment: Payment used by customer for purchase (3 methods are available – Cash, Credit card and Ewallet)
#
# COGS: Cost of goods sold
#
# Gross margin percentage: Gross margin percentage
#
# Gross income: Gross income
#
# Rating: Customer stratification rating on their overall shopping experience (On a scale of 1 to 10)

# %%
import numpy as np #Importing numpy library
import pandas as pd #Importing pandas library
import matplotlib.pyplot as plt #Importing matplot library
import seaborn as sns # Importing seaborn library

# %%
data=pd.read_excel("supermarket_sales.xlsx") # read func is used to read the supermarket_sales file
data #print output
# Out:
#       Invoice ID Branch city code  Customer type  Gender Product code  \
# 0    750-67-8428      A        CT1        Member  Female          PD1
# 1    226-31-3081      C        CT3        Normal  Female          PD2
# 2    631-41-3108      A        CT1        Normal    Male          PD3
# 3    123-19-1176      A        CT1        Member    Male          PD1
# 4    373-73-7910      A        CT1        Normal    Male          PD4
# ..           ...    ...        ...           ...     ...          ...
# 995  233-67-5758      C        CT3        Normal    Male          PD1
# 996  303-96-2227      B        CT9        Normal  Female          PD3
# 997  727-02-1313      A        CT1        Member    Male          PD5
# 998  347-56-2442      A        CT1        Normal    Male          PD3
# 999  849-09-3807      A        CT1        Member  Female          PD6
#
#     Unit price  Quantity   Tax 5%      Total       Date      Time  \
# ...

# %% [markdown]
# **CITY WITH CODES**
#
#
#
# 1.  CT1- YANGON
# 2.  CT2- NAYPYITAW
# 3.  CT3- MANDALAY

# %% [markdown]
# **PRODUCT LINE WITH CODES**
#
#
# 1.  PD1- HEALTH AND BEAUTY
# 2.  PD2- ELECTRONIC ACCESSORIES
# 3.  PD3- HOME AND LIFESTYLE
# 4.  PD4- SPORTS AND TRAVEL
# 5.  PD5- FOOD AND BEVERAGES
# 6.  PD6- FASHION AND ACCESSORIES

# %%
from pandas.core.frame import DataFrame #import dataframe
sm=DataFrame(data) # creating new variable to data

# %%
sm.isnull().head() #checking null values of first 5 rows
# Out:
#    Invoice ID  Branch  city code   Customer type  Gender  Product code  \
# 0       False   False       False          False   False         False
# 1       False   False       False          False   False         False
# 2       False   False       False          False   False         False
# 3       False   False       False          False   False         False
# 4       False   False       False          False   False         False
#
#    Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0       False     False   False  False  False  False    False  False
# 1       False     False   False  False  False  False    False  False
# 2       False     False   False  False  False  False    False  False
# 3       False     False   False  False  False  False    False  False
# 4       False     False   False  False  False  False    False  False
#
#    gross margin percentage  gross income  Rating
# 0                    False         False   False
# ...

# %%
sm.isnull().sum() #if null true otherwise false
# true = 1 and false 0
# Out:
# Invoice ID                 0
# Branch                     0
# city code                  0
# Customer type              0
# Gender                     0
# Product code               0
# Unit price                 4
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     7
# dtype: int64

# %%
sm.notnull().head() # opposite of isnull
# Out:
#    Invoice ID  Branch  city code   Customer type  Gender  Product code  \
# 0        True    True        True           True    True          True
# 1        True    True        True           True    True          True
# 2        True    True        True           True    True          True
# 3        True    True        True           True    True          True
# 4        True    True        True           True    True          True
#
#    Unit price  Quantity  Tax 5%  Total  Date  Time  Payment  cogs  \
# 0        True      True    True   True  True  True     True  True
# 1        True      True    True   True  True  True     True  True
# 2        True      True    True   True  True  True     True  True
# 3        True      True    True   True  True  True     True  True
# 4        True      True    True   True  True  True     True  True
#
#    gross margin percentage  gross income  Rating
# 0                     True          True    True
# ...

# %% [markdown]
# ##**QUESTIONS**
#
# ###**PART 1**

# %% [markdown]
# ##**1.Is your supermarket more popular with males or females?**

# %%
sns.countplot(x='Gender', data=sm) # x axis is am column.
plt.title("Figure : Count of Males and Females") # providing title to the plot
plt.show() # print output

# %% [markdown]
# **EXPLANATION:**
#
# 1. As the above plot mentioned in supermarket females are popular than males just by 1 or 2%.

# %% [markdown]
# ##**2.What does the customer rating look like and can you also comment on its skewness?**

# %%
sns.distplot(a=data.Rating, color='red',
             hist_kws={"edgecolor": 'white'}) # using disc plot with hist_kws to get the border line more visible. 
plt.title("Figure :Rating with skewness distribution") # providing title to the plot
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Figure :Rating with skewness distribution')

# %% [markdown]
# **EXPLANATION:**
#
# 1. The avg rating of all customers is 7.
# 2. No skewness on the left or right side of the distribution.

# %% [markdown]
# ##**3.What can you say about the aggregate sales across the branches?**

# %%
sns.countplot(sm['Branch']) #using count plot 
sm['Branch'].value_counts() #print output
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %% [markdown]
# **EXPLANATION:**
#
# 1.Branch A has higher sales compare to Branch B&C.
#
#
# 2.Branch B has higher than Branch C.
#
#
# 3.Branch C has lowest sales compare to Branch A & B.

# %% [markdown]
# ##**4.Which is the most popular payment method used by customers?**

# %%
sns.countplot(sm['Payment']) #using countplot and giving x-axis as payment
plt.title("Figure 1: Mode of Payments done by customers") #adiing title to the plot
plt.show() #print ouput
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **EXPLANATION:**
#
# The most popular payment method is in-fact E-wallet and not credit cards.Cash payment is also popular.

# %% [markdown]
# ##**PART-2**

# %% [markdown]
# ##**1.Does gross income affect customer ratings?**

# %%
sns.regplot(sm['Rating'], sm['gross income']) # using regplot to see the income affect on customer ratings.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **EXPLANATION:**
#
# 1. There will be no affect on gross income based on customer rating.

# %% [markdown]
# ##**2.Which is the most profitable branch?**

# %%
sns.scatterplot(x=sm['Branch'], y=sm['gross income']) #using scatter plot and providing x-axis and y-axis.

# %% [markdown]
# **EXPLANATION:**
#
# 1.By using scatter plot Branch C had slightly profitable compare to Branch A & B.

# %% [markdown]
# ##**3.Create a boxplot between Gender and Gross income and explain the results?**

# %%
sns.boxplot(x=sm['Gender'], y=sm['gross income']) # using box plot and comparing gender and gross income.

# %% [markdown]
# **EXPLANATION:**
#
# 1.Comparing the above mentioned box plot with gender amd gross income.
#
# 2.Females slightly had a high gross income compare to male.
#
# 3.The median value is slightly high compare to male.
#
# 4.Female max gross income has 48.
#
# 5.Male maxgross income has 45.

# %% [markdown]
# ##**4.Can you see any time trend in gross income?**

# %%
sns.set_style("whitegrid") #creating grid lines in plot 
sns.lineplot(x ='Date', y ='gross income', data = sm) #using box plot with date and gross income to know the trend in income.

# %% [markdown]
# **EXPLANATION:**
#
# 1.No particular time trend is observed except for some days when the gross income is pretty high or pretty low.
#
# 2.Overall it remains at a certain average level.

# %% [markdown]
# ##**5.What is the spending pattern of both males and females, meaning in which category do they spend more?**

# %%
plt.figure(figsize=(12, 5)) # providing fig size
plt.title('Total Monthly transaction by Gender') # title of count plot
sns.countplot(sm['Product code'], hue = sm.Gender) #providing x-axis is product line and hue (male/female)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **EXPLANATION:**
#
# Both male and female is spending more in PD6(FASHION AND ACCESSORIES).

# %% [markdown]
# ##**6.How many products are bought by customers?**

# %%
sns.displot(sm["Quantity"]) # quantity of products brought by customers
plt.title(" FIGURE: PRODUCTS BROUGHT BY THE CUSTOMERS")# title of the plot
# Out:
# Text(0.5, 1.0, ' FIGURE: PRODUCTS BROUGHT BY THE CUSTOMERS')

# %% [markdown]
# **EXPLANATIONS:**
#
# 1.Most of the customers buying 10 products.

# %% [markdown]
# ##**7.Which day of the week has maximum sales?**

# %%
sns.lineplot(x="gross income",y="Date",data=sm) # comparing gross income with date

# %% [markdown]
# ##**8.Which hour of the day is busiest?**

# %%
sm.dtypes #checking data types
sns.lineplot(x="Date", y = 'Quantity',data =sm) # comparing with date and quantity
plt.title("Product Sales per Hour")# plot title
# Out:
# Text(0.5, 1.0, 'Product Sales per Hour')

# %% [markdown]
# ##9.Which product line should your supermarket focus on?**

# %%
sns.boxenplot(y = 'Product code', x = 'Quantity', data=sm) # comparing product and quantity
plt.title("FIGURE: COMPARING PRODUCT AND QUANTITY") # Title to plot
# Out:
# Text(0.5, 1.0, 'FIGURE: COMPARING PRODUCT AND QUANTITY')

# %% [markdown]
# **EXPLANATION:**
#
# 1. PD5-(FOOD AND BEVERGES)AND PD6-(FASHION AND ACCESSORIES) has low quantity of products.

# %% [markdown]
# ##**10.Which city should be chosen for expansion and what products should be focussed on?**

# %%
sns.barplot(sm['Branch'],sm['gross income']) # highest gross income as city wise
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# **EXPLANATION:**
#
# Branch C(MANDALAY) is the most profitable city, hence the expansion plan should be based on this city.

# %%
sns.countplot(y ='Product code', hue = "Branch", data = sm) # assigining y-axis product code and hue as branch.
plt.xlabel('Count')# counting the product code 
plt.show()# print output

# %% [markdown]
# **EXPLANATION:**
# (PD5)-Food and beverages and (PD6)-Fashion accessories are the most sold product in MANDALAY and these products should be focused on for expansion along (PD2)-with electronic accessories.
